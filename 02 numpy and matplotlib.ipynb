# %%
m = 5
c = -1
x = [0, 1, 2, 3, 4, 5, 6]

# %%
y = None

# %%
print(y)
# Out:
# None

# %%
import numpy as np 
None

# %%
X = np.array(x)
Y = m*X + c

# %%
print(Y)
# Out:
# [-1  4  9 14 19 24 29]

# %%
import matplotlib.pyplot as plt

X = np.array(x)
Y = m*X + c

plt.scatter(X, Y, s=None, c = "black", alpha=0.8)
plt.show()
None
